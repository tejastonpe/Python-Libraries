# %% [markdown]
# 1. Write a program to draw box plot of life expectancy by continent for a data set given in a
# url
# https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapmind
# er-FiveYearData.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv"
gapminder_data = pd.read_csv(url)

plt.figure(figsize=(12, 8))
sns.boxplot(data=gapminder_data, x='continent', y='lifeExp', palette='pastel')

plt.xlabel('Continent')
plt.ylabel('Life Expectancy')
plt.title('Box Plot of Life Expectancy by Continent')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17060\980380318.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=gapminder_data, x='continent', y='lifeExp', palette='pastel')

# %% [markdown]
# 2. Write a program to draw a box plot of day by tips for a dataset given in a url
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
tips_data = pd.read_csv(url)

plt.figure(figsize=(10, 6))
sns.boxplot(data=tips_data, x='day', y='tip', palette='muted')

plt.xlabel('Day')
plt.ylabel('Tip ($)')
plt.title('Box Plot of Tips by Day')

plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17060\2760335685.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips_data, x='day', y='tip', palette='muted')
