# %% [markdown]
# 1. Write a program to draw a violin plot of sex against total_bill for a given dataset
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Tips dataset from the URL
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
tips_data = pd.read_csv(url)

# Creating the violin plot
plt.figure(figsize=(8, 6))
sns.violinplot(data=tips_data, x='sex', y='total_bill', palette='muted')

# Adding labels and title
plt.xlabel('Sex')
plt.ylabel('Total Bill ($)')
plt.title('Violin Plot of Sex vs Total Bill')

# Display the violin plot
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_20684\1272030005.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=tips_data, x='sex', y='total_bill', palette='muted')

# %% [markdown]
# 2. Write a program to draw a violin plot of “species” against “sepal length” for a dataset
# given in a url
# https://github.com/mwaskom/seaborn-data/blob/master/iris.csv

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
iris_data = pd.read_csv(url)

plt.figure(figsize=(8, 6))
sns.violinplot(data=iris_data, x='species', y='sepal_length', palette='muted')

plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.title('Violin Plot of Species vs Sepal Length')

plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_20684\380245148.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=iris_data, x='species', y='sepal_length', palette='muted')
