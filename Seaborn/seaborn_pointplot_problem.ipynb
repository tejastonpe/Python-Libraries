# %% [markdown]
# 1. Write a program to draw a point plot for sex against survived for a dataset given in url
# https://github.com/mwaskom/seaborn-data/blob/master/titanic.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
titanic_data = pd.read_csv(url)

plt.figure(figsize=(8, 6))
sns.pointplot(data=titanic_data, x='sex', y='survived', ci=None)

plt.xlabel('Sex')
plt.ylabel('Survived (mean)')
plt.title('Point Plot of Survival by Sex')

plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_22076\550321369.py:11: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(data=titanic_data, x='sex', y='survived', ci=None)
